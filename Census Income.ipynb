# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Census%20Income/Census%20Income.csv')
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
df.tail()
# Out:
#        Age      Workclass  Fnlwgt    Education  Education_num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %% [markdown]
# There are 32560 rows and 15 columns present in this dataset.

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %% [markdown]
# There are only two types of data available in our dataset: int64 and object

# %% [markdown]
# # Data Analysis

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# There are no null values present in this dataset.

# %%
df.nunique().to_frame("No. of unique values")
# Out:
#                 No. of unique values
# Age                               73
# Workclass                          9
# Fnlwgt                         21647
# Education                         16
# Education_num                     16
# Marital_status                     7
# Occupation                        15
# Relationship                       6
# Race                               5
# Sex                                2
# Capital_gain                     119
# Capital_loss                      92
# Hours_per_week                    94
# Native_country                    42
# Income                             2

# %% [markdown]
# We can see that in column 'Fnlwgt' more than 65% of the values are unique so we can drop this column as large number of unique values can cause difficulty in prediction and anlysis.

# %%
#dropping column
df.drop(columns={'Fnlwgt'}, axis=1, inplace=True)

# %%
df.describe()
# Out:
#                 Age  Education_num  Capital_gain  Capital_loss  Hours_per_week
# count  32560.000000   32560.000000  32560.000000  32560.000000    32560.000000
# mean      38.581634      10.080590   1077.615172     87.306511       40.437469
# std       13.640642       2.572709   7385.402999    402.966116       12.347618
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       48.000000      12.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000

# %% [markdown]
# From above statistical information we can say :
#
# 1) statistical data is possible only for numerical column and not for categorical columns.
# 2) There is no null value present in the dataset as the count of all the columns is equal to rows present in the data.
# 3) The mean value in Education_num and Hours_per_week column are almost equal to median which means there is normal distribution in this column.
# 4) The mean value in other columns is greater than the median which means data is skewed to the right in this column.
# 5) There is a huge difference in 75% and max value of these two columns hence, there are outliers present in the data.

# %%
#checking the count of each unique value in columns
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64
#
#
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
#
#
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64
#
#
# 9     10501
# 10     7291
# 13     5354
# 14     1723
# 11     1382
# 7      1175
# ...

# %%
#separating numerical and categorical columns
numerical_col=[]
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_col.append(i)
    else:
        numerical_col.append(i)

# %%
print('categorical column:',categorical_col)
print('numerical column:',numerical_col)
# Out:
# categorical column: ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']
# numerical column: ['Age', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week']

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10,3))
print(df["Workclass"].value_counts())
ax= sns.countplot(x='Workclass',data=df)
plt.show()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
plt.figure(figsize=(20,8))
print(df["Education"].value_counts())
ax= sns.countplot(x='Education',data=df)
plt.show()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
plt.figure(figsize=(10,3))
print(df["Marital_status"].value_counts())
ax= sns.countplot(x='Marital_status',data=df)
plt.show()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
plt.figure(figsize=(20,8))
print(df["Occupation"].value_counts())
ax= sns.countplot(x='Occupation',data=df)
plt.show()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
plt.figure(figsize=(20,5))
print(df["Relationship"].value_counts())
ax= sns.countplot(x='Relationship',data=df)
plt.show()
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
plt.figure(figsize=(20,5))
print(df["Race"].value_counts())
ax= sns.countplot(x='Race',data=df)
plt.show()
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %%
plt.figure(figsize=(18,6))
print(df["Sex"].value_counts())
ax= sns.countplot(x='Sex',data=df)
plt.show()
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=(20,5))
print(df["Income"].value_counts())
ax= sns.countplot(x='Income',data=df)
plt.show()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
plt.figure(figsize=(20,5))
print(df["Native_country"].value_counts())
ax= sns.countplot(x='Native_country',data=df)
plt.show()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(),cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# This heat map shows the correlation between different columns. Some columns are positively correlated with each other and some are negatively correlated with each other.

# %%
# Encoding categorical columns
from sklearn.preprocessing import OrdinalEncoder
encoder= OrdinalEncoder()
df[categorical_col]= encoder.fit_transform(df[categorical_col])
print("\nTransformed DataFrame:")
print(df)
# Out:
# Transformed DataFrame:
#        Age  Workclass  Education  Education_num  Marital_status  Occupation  \
# 0       50        6.0        9.0             13             2.0         4.0
# 1       38        4.0       11.0              9             0.0         6.0
# 2       53        4.0        1.0              7             2.0         6.0
# 3       28        4.0        9.0             13             2.0        10.0
# 4       37        4.0       12.0             14             2.0         4.0
# ...    ...        ...        ...            ...             ...         ...
# 32555   27        4.0        7.0             12             2.0        13.0
# 32556   40        4.0       11.0              9             2.0         7.0
# 32557   58        4.0       11.0              9             6.0         1.0
# 32558   22        4.0       11.0              9             4.0         1.0
# 32559   52        5.0       11.0              9             2.0         4.0
#
# ...

# %%
#detecting outliers
for column in df:
    plt.figure()
    df.boxplot([column])

# %%
#find the limits
for columns in df.columns:
    upper_limit= df[columns].mean() + 3*df[columns].std()
    lower_limit= df[columns].mean() - 3*df[columns].std()
    print('Upper Limit:',upper_limit)
    print('Lower Limit:',lower_limit)
# Out:
# Upper Limit: 79.50355938902604
# Lower Limit: -2.3402915757582363
# Upper Limit: 8.236432193324184
# Lower Limit: -0.49884005573204604
# Upper Limit: 21.90919947789533
# Lower Limit: -1.3127007063965586
# Upper Limit: 17.798716584905506
# Lower Limit: 2.362462776273855
# Upper Limit: 7.130469231063211
# Lower Limit: -1.9068820074759874
# Upper Limit: 19.25933844579571
# Lower Limit: -6.113515349972613
# Upper Limit: 6.266757083548676
# Lower Limit: -3.3740052407968335
# Upper Limit: 6.212297522980972
# Lower Limit: 1.1193978087143601
# Upper Limit: 2.0807255827992783
# Lower Limit: -0.7423349194086147
# Upper Limit: 23233.824167639767
# Lower Limit: -21078.593823659423
# Upper Limit: 1296.2048598954996
# Lower Limit: -1121.5918377824776
# Upper Limit: 77.48032346291092
# Lower Limit: 3.394615112027651
# Upper Limit: 60.19047158024506
# Lower Limit: 13.247120557347074
# Upper Limit: 1.5235748694065991
# Lower Limit: -1.0419409627726925

# %%
#find the outliers
for column in df.columns:
    df.loc[(df[column] > upper_limit) | (df[column] < lower_limit)]

# %%
#capping the outliers
for column in df.columns:
    df.loc[(df[column] > upper_limit), column ] =upper_limit
    df.loc[(df[column] < lower_limit), column ] =lower_limit

# %%
for column in df:
    plt.figure()
    df.boxplot([column])

# %%
df.describe()
# Out:
#                 Age     Workclass     Education  Education_num  \
# count  3.256000e+04  32560.000000  32560.000000   32560.000000
# mean   1.523575e+00      1.422226      1.461023       1.522755
# std    1.111572e-12      0.358759      0.269254       0.020706
# min    1.523575e+00      0.000000      0.000000       1.000000
# 25%    1.523575e+00      1.523575      1.523575       1.523575
# 50%    1.523575e+00      1.523575      1.523575       1.523575
# 75%    1.523575e+00      1.523575      1.523575       1.523575
# max    1.523575e+00      1.523575      1.523575       1.523575
#
#        Marital_status    Occupation  Relationship          Race           Sex  \
# count    32560.000000  32560.000000  32560.000000  32560.000000  32560.000000
# mean         1.315304      1.376729      0.772706      1.492315      0.669195
# std          0.523046      0.376251      0.668344      0.173041      0.470510
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# ...

# %%
#separating target column and columns not necessary in the analysis from data
X= df.drop(["Income"],axis=1)
Y= df["Income"]

# %%
print(X)
print(Y)
# Out:
#             Age  Workclass  Education  Education_num  Marital_status  \
# 0      1.523575   1.523575   1.523575       1.523575        1.523575
# 1      1.523575   1.523575   1.523575       1.523575        0.000000
# 2      1.523575   1.523575   1.000000       1.523575        1.523575
# 3      1.523575   1.523575   1.523575       1.523575        1.523575
# 4      1.523575   1.523575   1.523575       1.523575        1.523575
# ...         ...        ...        ...            ...             ...
# 32555  1.523575   1.523575   1.523575       1.523575        1.523575
# 32556  1.523575   1.523575   1.523575       1.523575        1.523575
# 32557  1.523575   1.523575   1.523575       1.523575        1.523575
# 32558  1.523575   1.523575   1.523575       1.523575        1.523575
# 32559  1.523575   1.523575   1.523575       1.523575        1.523575
#
#        Occupation  Relationship      Race  Sex  Capital_gain  Capital_loss  \
# ...

# %% [markdown]
# # Splitting the data into training and testing data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X,Y,test_size=0.2,random_state=2)
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (32560, 13) (26048, 13) (6512, 13)

# %% [markdown]
# # Creating model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model= LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction= model.predict(X_train)
training_data_accuracy= accuracy_score(X_train_prediction, Y_train)
print('Accuracy:',training_data_accuracy)
# Out:
# Accuracy: 0.7938037469287469

# %% [markdown]
# # Prediction

# %%
input_data= (37,4.0,12.0,14,2.0,4.0,5.0,4.0,0.0,0,0,40,39.0 )
data= np.asarray(input_data)
reshape= data.reshape(1,-1)

# %%
output= model.predict(reshape)
print(output)
# Out:
# [0.]

# %%
if(output[0]==1):
    print('>50K')
else:
    print('<=50K')
# Out:
# <=50K
